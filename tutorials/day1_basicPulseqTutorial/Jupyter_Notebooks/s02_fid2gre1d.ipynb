# %% [markdown]
# <a href="https://colab.research.google.com/github/pulseq/ISMRM-Virtual-Meeting--February-24-26-2026/blob/main/tutorials/day1_basicPulseqTutorial/Jupyter_Notebooks/s02_fid2gre1d.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # from FID to 1D GRE
# **Exercise**:
# This exercise starts from the FID. Now extend the FID to 1D GRE by inserting the trapezoid readout gradient and its pre-phaser to the sequence.

# %%
#@title GRE 1D in a pixel phantom - environment setup
# !pip show pypulseq || pip install pypulseq==1.4.2
import pypulseq as pp

# for MRzero simulation
# !pip show MRzeroCore || pip install MRzeroCore
# !wget https://github.com/MRsources/MRzero-Core/raw/main/documentation/playground_mr0/util.py &> /dev/null
#!wget https://github.com/MRsources/MRzero-Core/raw/main/documentation/playground_mr0/numerical_brain_cropped.mat &> /dev/null
import MRzeroCore as mr0

import numpy as np
from matplotlib import pyplot as plt
# Out:
# WARNING: Package(s) not found: pypulseq
# Collecting pypulseq==1.4.2
#   Downloading pypulseq-1.4.2-py3-none-any.whl.metadata (6.7 kB)
# Collecting coverage>=6.2 (from pypulseq==1.4.2)
#   Downloading coverage-7.13.4-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (8.5 kB)
# Requirement already satisfied: matplotlib>=3.5.2 in /usr/local/lib/python3.12/dist-packages (from pypulseq==1.4.2) (3.10.0)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.12/dist-packages (from pypulseq==1.4.2) (2.0.2)
# Requirement already satisfied: scipy>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from pypulseq==1.4.2) (1.16.3)
# Collecting sigpy>=0.1.26 (from pypulseq==1.4.2)
#   Downloading sigpy-0.1.27-1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.2->pypulseq==1.4.2) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.2->pypulseq==1.4.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.2->pypulseq==1.4.2) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.2->pypulseq==1.4.2) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.2->pypulseq==1.4.2) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.2->pypulseq==1.4.2) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.2->pypulseq==1.4.2) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.2->pypulseq==1.4.2) (2.9.0.post0)
# Requirement already satisfied: pywavelets in /usr/local/lib/python3.12/dist-packages (from sigpy>=0.1.26->pypulseq==1.4.2) (1.9.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (from sigpy>=0.1.26->pypulseq==1.4.2) (0.60.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from sigpy>=0.1.26->pypulseq==1.4.2) (4.67.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5.2->pypulseq==1.4.2) (1.17.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba->sigpy>=0.1.26->pypulseq==1.4.2) (0.43.0)
# Downloading pypulseq-1.4.2-py3-none-any.whl (278 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.0/278.0 kB 8.4 MB/s eta 0:00:00
# Downloading coverage-7.13.4-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (254 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.1/254.1 kB 21.5 MB/s eta 0:00:00
# Downloading sigpy-0.1.27-1-py3-none-any.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.7/108.7 kB 8.9 MB/s eta 0:00:00
# Installing collected packages: coverage, sigpy, pypulseq
# Successfully installed coverage-7.13.4 pypulseq-1.4.2 sigpy-0.1.27
# WARNING: Package(s) not found: MRzeroCore
# Collecting MRzeroCore
#   Downloading mrzerocore-0.4.5-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.0 kB)
# Collecting ismrmrd (from MRzeroCore)
#   Downloading ismrmrd-1.14.2-py3-none-any.whl.metadata (927 bytes)
# Requirement already satisfied: matplotlib>=3.5 in /usr/local/lib/python3.12/dist-packages (from MRzeroCore) (3.10.0)
# Collecting pydisseqt>=0.1.13 (from MRzeroCore)
#   Downloading pydisseqt-0.2.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (280 bytes)
# Requirement already satisfied: pypulseq in /usr/local/lib/python3.12/dist-packages (from MRzeroCore) (1.4.2)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.12/dist-packages (from MRzeroCore) (2.32.4)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from MRzeroCore) (0.25.2)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.12/dist-packages (from MRzeroCore) (1.16.3)
# Collecting torchkbnufft (from MRzeroCore)
#   Downloading torchkbnufft-1.5.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: torch>=1.12 in /usr/local/lib/python3.12/dist-packages (from MRzeroCore) (2.10.0+cpu)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from MRzeroCore) (4.67.3)
# Requirement already satisfied: nibabel in /usr/local/lib/python3.12/dist-packages (from MRzeroCore) (5.3.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5->MRzeroCore) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5->MRzeroCore) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5->MRzeroCore) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5->MRzeroCore) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5->MRzeroCore) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5->MRzeroCore) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5->MRzeroCore) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5->MRzeroCore) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5->MRzeroCore) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20->MRzeroCore) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20->MRzeroCore) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20->MRzeroCore) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20->MRzeroCore) (2026.1.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.12->MRzeroCore) (3.24.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12->MRzeroCore) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.12->MRzeroCore) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12->MRzeroCore) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12->MRzeroCore) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12->MRzeroCore) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12->MRzeroCore) (2025.3.0)
# Requirement already satisfied: h5py>=2.3 in /usr/local/lib/python3.12/dist-packages (from ismrmrd->MRzeroCore) (3.15.1)
# Collecting xsdata>=22.12 (from ismrmrd->MRzeroCore)
#   Downloading xsdata-26.2-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: coverage>=6.2 in /usr/local/lib/python3.12/dist-packages (from pypulseq->MRzeroCore) (7.13.4)
# Requirement already satisfied: sigpy>=0.1.26 in /usr/local/lib/python3.12/dist-packages (from pypulseq->MRzeroCore) (0.1.27)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->MRzeroCore) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->MRzeroCore) (2026.2.16)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->MRzeroCore) (0.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5->MRzeroCore) (1.17.0)
# Requirement already satisfied: pywavelets in /usr/local/lib/python3.12/dist-packages (from sigpy>=0.1.26->pypulseq->MRzeroCore) (1.9.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (from sigpy>=0.1.26->pypulseq->MRzeroCore) (0.60.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.12->MRzeroCore) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.12->MRzeroCore) (3.0.3)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba->sigpy>=0.1.26->pypulseq->MRzeroCore) (0.43.0)
# Downloading mrzerocore-0.4.5-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (377 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.3/377.3 kB 9.9 MB/s eta 0:00:00
# Downloading pydisseqt-0.2.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (474 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.0/475.0 kB 27.1 MB/s eta 0:00:00
# Downloading ismrmrd-1.14.2-py3-none-any.whl (32 kB)
# Downloading torchkbnufft-1.5.2-py3-none-any.whl (37 kB)
# Downloading xsdata-26.2-py3-none-any.whl (235 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.6/235.6 kB 20.1 MB/s eta 0:00:00
# Installing collected packages: xsdata, pydisseqt, ismrmrd, torchkbnufft, MRzeroCore
# Successfully installed MRzeroCore-0.4.5 ismrmrd-1.14.2 pydisseqt-0.2.1 torchkbnufft-1.5.2 xsdata-26.2
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
#@title 1D GRE in a pixel phantom - sequence

# Define number of ADC samples
fov = 256e-3
Nread = 256
TE = 10e-3 # echo time
TR = 10 # repetition time

# Setup scanner limits
sys = pp.Opts(
    max_grad=28, grad_unit='mT/m', max_slew=150, slew_unit='T/m/s',
    rf_ringdown_time=20e-6, rf_dead_time=100e-6,
    adc_dead_time=20e-6, grad_raster_time=10e-6)

# Setup sequence object
seq = pp.Sequence(sys)

# Define RF event, 90-deg hard pulse for excitation
rf_ex = pp.make_block_pulse(flip_angle=90*np.pi/180, duration=4e-3, phase_offset=0*np.pi/180, delay=10e-6, system=sys)

# Define ADC event
adc = pp.make_adc(num_samples=Nread, duration=5.12e-3, phase_offset=0*np.pi/180, delay=10e-6, system=sys)

# Define readout gradients
deltak = 1/fov
gx = pp.make_trapezoid(channel='x', flat_area=Nread*deltak, flat_time=adc.dwell*adc.num_samples, system=sys) # readout gradient
adc.delay = gx.rise_time
gx_pre = pp.make_trapezoid(channel='x', area=-gx.area/2, duration=4e-3, system=sys) # readout pre-phaser

# Calculate timing
delayTE = TE - rf_ex.shape_dur/2 - rf_ex.ringdown_time - pp.calc_duration(gx)/2
delayTR = TR - pp.calc_duration(rf_ex) - delayTE - pp.calc_duration(gx)

# ======
# CONSTRUCT SEQUENCE
# ======
seq.add_block(rf_ex)
seq.add_block(pp.make_delay(delayTE))
seq.add_block(adc)
seq.add_block(pp.make_delay(delayTR))

# Check timing
(ok, error_report) = seq.check_timing()  # Check whether the timing of the sequence is correct
if ok:
    print("Timing check passed successfully")
else:
    print("Timing check failed. Error listing follows:")
    [print(e) for e in error_report]

# Plot sequence diagram
time_range = [0, 0.02]
seq.plot(time_range=time_range, time_disp='ms', show_blocks=True)

# Plot k-space trajectory
k_traj_adc, k_traj, t_excitation, t_refocusing, t_adc = seq.calculate_kspace()

plt.figure()
plt.plot(k_traj[0],k_traj[1])
plt.plot(k_traj_adc[0],k_traj_adc[1],'.')

# Prepare the sequence output for the scanner
seq.set_definition('Name', 'fid')
seq.write('s02_fid2gre1d.seq')
# Out:
# Timing check passed successfully
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# 'eaec0f335805721ba25c5896f44c0b6f'

# %%
#@title 1D GRE in a pixel phantom - simulation
# %% SETUP SPIN SYSTEM/object on which we can run the MR sequence .seq from above
# set phantom manually to a pixel phantom. Coordinate system is [-0.5, 0.5]^3
dB0 = 0
obj_p = mr0.CustomVoxelPhantom(
        pos=[[0., 0., 0.]],
        PD=[1.0],
        T1=[3.0],
        T2=[0.5],
        T2dash=[30e-3],
        D=[0.0],
        B0=0,
        voxel_size=0.1,
        voxel_shape="box"
    )
# Manipulate loaded data
obj_p.B0+=dB0
obj_p.D*=0
obj_p.plot()
# Convert Phantom into simulation data
obj_p=obj_p.build()

# %% SIMULATE  the external.seq file and add acquired signal to ADC plot
# Read in the sequence
seq0 = mr0.Sequence.import_file("s02_fid2gre1d.seq")
# Simulate the sequence
graph=mr0.compute_graph(seq0, obj_p, 200, 1e-3)
signal=mr0.execute_graph(graph, seq0, obj_p)
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/functional.py:505: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:4381.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# CustomVoxelPhantom
# Voxel shape: box
# Voxel size: tensor([0.1000, 0.1000, 0.1000])
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Calculating repetition 1 / 1 - done

# %%
#@title 1D GRE in a pixel phantom - reconstruction
# 1D FFT
def fft_1d(x):
    return np.fft.fftshift(np.fft.fftn(np.fft.ifftshift(x)))

# detailed ADC plot for one repetition
plt.figure()
plt.title('ADC signal')
# time axis
time_axis=np.linspace(1, Nread, Nread)*adc.dwell ;
plt.plot(time_axis, np.real(signal), label='real')
plt.plot(time_axis, np.imag(signal), label='imag')
plt.plot(time_axis, np.abs(signal), label='abs')
plt.grid()
plt.legend(loc="upper right")
plt.xlabel('time (ADC)/s')
plt.ylabel('Amplitude')

# 1D FFT reconstruction
spectrum = fft_1d(signal)

# frequency axis
freq_axis = np.linspace(-Nread/2, Nread/2-1, Nread)/(adc.dwell*adc.num_samples)

plt.figure()
plt.title('Spectrum')
plt.plot(freq_axis, np.abs(spectrum))
plt.xlabel('Frequency/Hz')
plt.ylabel('Amplitude')
# Out:
# /tmp/ipython-input-1706176005.py:13: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   plt.plot(time_axis, np.abs(signal), label='abs')
# Text(0, 0.5, 'Amplitude')
